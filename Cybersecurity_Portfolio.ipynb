# %% [markdown]
# <a href="https://colab.research.google.com/github/wmendozarCIFO/Cybersecurity-Portfolio/blob/main/Cybersecurity_Portfolio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pwd
# Out:
# '/content'

# %%
ls -l
# Out:
# total 4
# drwxr-xr-x 1 root root 4096 Apr  2 13:31 sample_data/
